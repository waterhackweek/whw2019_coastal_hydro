# %%
import pandas as pd
import numpy as np

# %%
#table1 = pd.read_table('./table_hdr')

# %%
#print(table1)

# %%
#table2 = table1.drop([0,1,2,3,4])
#table3 = table2.iloc[::12, :]
#print(table3)
#table3.to_csv('table3hr.csv')

# %%
tablepc = pd.read_csv('./table3pc.csv')
tablepc[0:5]
# Out:
#     n        ID   Code Scode     Date   Time  Rainfall(in)  Rainfall(mm)  \
# 0   1  1560029C  ANHH1    PC  3/17/19   2:00        146.65       3724.91
# 1   2  1560029C  ANHH1    PC  3/17/19   5:00        146.65       3724.91
# 2  29  1560029C  ANHH1    PC  3/17/19   8:00        146.65       3724.91
# 3  41  1560029C  ANHH1    PC  3/17/19  11:00        146.65       3724.91
# 4  53  1560029C  ANHH1    PC  3/17/19  13:00        146.65       3724.91
#
#   Rainfall Rate ( mm/hr)
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0

# %%
# # create a new dataframe
# df = pd.DataFrame()

# %%
# df['datetime'] = pd.to_datetime(tablepc.Date + " " + tablepc.Time)
# df = df.drop_duplicates(subset='datetime', keep='first')
# df = df.set_index('datetime')

# %%
df
# Out:
#                            ANHH1 HNPH1        KPIH1 NUUH1 LIHH1        WUHH1  \
# datetime
# 2019-03-17 02:00:00            0   NaN  0.447816111   NaN   NaN          NaN
# 2019-03-17 05:00:00            0   NaN            0   NaN   NaN          NaN
# 2019-03-17 08:00:00            0   NaN            0   NaN   NaN          NaN
# 2019-03-17 11:00:00            0   NaN            0   NaN   NaN          NaN
# 2019-03-17 13:00:00            0   NaN          NaN   NaN   NaN            0
# 2019-03-17 16:00:00            0   NaN            0   NaN   NaN          NaN
# 2019-03-17 19:00:00            0   NaN            0   NaN   NaN          NaN
# 2019-03-17 22:00:00            0   NaN            0   NaN   NaN          NaN
# 2019-03-18 00:00:00            0   NaN          NaN     0   NaN            0
# 2019-03-18 03:00:00            0   NaN            0     0   NaN          NaN
# 2019-03-18 06:00:00            0     0            0     0   NaN          NaN
# ...

# %%
df = pd.DataFrame()
# create columns for each site
sites=tablepc.Code.unique()
for site in sites:
    print(site)
    df[site] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==site]
    
#df['1'] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==sites[0]]
#df['2'] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==sites[1]]
#df['3'] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==sites[3]]
# Out:
# ANHH1
# HNPH1
# KPIH1
# NUUH1
# LIHH1
# WUHH1
# AHUH1
# HAUH1
# WBHH1
# KASH1
# PUKH1
# P36
# WHSH1
# MOGH1
# HAKH1
# WISH1
# WLDH1
# WKRH1
# KNRH1
# KMHH1
# STVH1
# MAUH1
# MOAH1
# NIUH1
# OFSH1
# PFSH1
# PUNH1
# LUAH1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-a73cb527dc32> in <module>()
#       4 for site in sites:
#       5     print(site)
# ----> 6     df[site] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==site]
#       7
#       8 #df['1'] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==sites[0]]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ...

# %%
tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code=='LUAH1']
# Out:
# datetime
# 2019-03-17 03:30:00    -0.259785556
# 2019-03-17 06:30:00               0
# 2019-03-17 09:30:00               0
# 2019-03-17 12:30:00               0
# 2019-03-17 15:30:00               0
# 2019-03-17 18:30:00               0
# 2019-03-17 21:30:00               0
# 2019-03-18 00:30:00               0
# 2019-03-18 03:30:00               0
# 2019-03-18 06:30:00               0
# 2019-03-18 09:30:00               0
# 2019-03-18 12:30:00               0
# 2019-03-18 15:30:00               0
# 2019-03-18 18:30:00               0
# 2019-03-18 21:30:00               0
# 2019-03-19 00:30:00               0
# 2019-03-19 03:30:00               0
# 2019-03-19 06:30:00               0
# 2019-03-19 09:30:00               0
# 2019-03-19 12:30:00               0
# 2019-03-19 15:30:00               0
# 2019-03-19 18:30:00               0
# 2019-03-19 21:30:00               0
# 2019-03-20 00:30:00               0
# 2019-03-20 03:30:00               0
# 2019-03-20 06:30:00               0
# ...

# %%
sites=tablepc.Code.unique()

# %%
sites[0]
# Out:
# 'ANHH1'

# %%
# create columns for each site
sites=tablepc.Code.unique()
for site in sites:
    df[site] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==site]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-37492295ea1f> in <module>()
#       2 sites=tablepc.Code.unique()
#       3 for site in sites:
# ----> 4     df[site] = tablepc['Rainfall Rate ( mm/hr)'][tablepc.Code==site]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ...

# %%
# create datetime column
tablepc['datetime'] = tablepc.Date + " " + tablepc.Time
tablepc.datetime = pd.to_datetime(tablepc.datetime)

# %%
tablepc
# Out:
#            n        ID   Code Scode     Date   Time  Rainfall(in)  \
# 0          1  1560029C  ANHH1    PC  3/17/19   2:00        146.65
# 1          2  1560029C  ANHH1    PC  3/17/19   5:00        146.65
# 2         29  1560029C  ANHH1    PC  3/17/19   8:00        146.65
# 3         41  1560029C  ANHH1    PC  3/17/19  11:00        146.65
# 4         53  1560029C  ANHH1    PC  3/17/19  13:00        146.65
# 5         65  1560029C  ANHH1    PC  3/17/19  16:00        146.65
# 6         77  1560029C  ANHH1    PC  3/17/19  19:00        146.65
# 7         89  1560029C  ANHH1    PC  3/17/19  22:00        146.65
# 8        101  1560029C  ANHH1    PC  3/18/19   0:00        146.65
# 9        113  1560029C  ANHH1    PC  3/18/19   3:00        146.65
# 10       125  1560029C  ANHH1    PC  3/18/19   6:00        146.65
# 11       137  1560029C  ANHH1    PC  3/18/19   9:00        146.65
# 12       149  1560029C  ANHH1    PC  3/18/19  11:17        146.65
# ...

# %%
tablepc = tablepc.set_index('datetime')

# %%
tablepc
# Out:
#                           n        ID   Code Scode     Date   Time  \
# datetime
# 2019-03-17 02:00:00       1  1560029C  ANHH1    PC  3/17/19   2:00
# 2019-03-17 05:00:00       2  1560029C  ANHH1    PC  3/17/19   5:00
# 2019-03-17 08:00:00      29  1560029C  ANHH1    PC  3/17/19   8:00
# 2019-03-17 11:00:00      41  1560029C  ANHH1    PC  3/17/19  11:00
# 2019-03-17 13:00:00      53  1560029C  ANHH1    PC  3/17/19  13:00
# 2019-03-17 16:00:00      65  1560029C  ANHH1    PC  3/17/19  16:00
# 2019-03-17 19:00:00      77  1560029C  ANHH1    PC  3/17/19  19:00
# 2019-03-17 22:00:00      89  1560029C  ANHH1    PC  3/17/19  22:00
# 2019-03-18 00:00:00     101  1560029C  ANHH1    PC  3/18/19   0:00
# 2019-03-18 03:00:00     113  1560029C  ANHH1    PC  3/18/19   3:00
# 2019-03-18 06:00:00     125  1560029C  ANHH1    PC  3/18/19   6:00
# 2019-03-18 09:00:00     137  1560029C  ANHH1    PC  3/18/19   9:00
# 2019-03-18 11:17:00     149  1560029C  ANHH1    PC  3/18/19  11:17
# ...

# %%
tablepc['datetime']=pd.to_datetime(tablepc[['Date','Time']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-a1445b9e8bc7> in <module>()
# ----> 1 tablepc['datetime']=pd.to_datetime(tablepc[['Date','Time']])
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     374         result = Series(values, index=arg.index, name=arg.name)
#     375     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
# --> 376         result = _assemble_from_unit_mappings(arg, errors=errors)
#     377     elif isinstance(arg, ABCIndexClass):
#     378         result = _convert_listlike(arg, box, format, name=arg.name)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _assemble_from_unit_mappings(arg, errors)
# ...

# %%
tablept = tablepc.rename(columns={'Rainfall(in)': 'Rainfall_in', 'Rainfall(mm)': 'Rainfall_mm', 'Rainfall( mm/hr)':'Rainfall_mmhr'}, inplace=True)
print(tablept)
# Out:
# None

# %%
tabplepct = tablept.drop(['n', 'ID', 'Scode', 'Rainfall_in','Rainfall_mm'], axis=1)
print(tablepct)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-5a0f54a6f665> in <module>()
# ----> 1 tabplepct = tablept.drop(['n', 'ID', 'Scode', 'Rainfall_in','Rainfall_mm'], axis=1)
#       2 print(tablepct)
#
# AttributeError: 'NoneType' object has no attribute 'drop'
