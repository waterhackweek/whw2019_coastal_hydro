# %% [markdown]
# This notebook fixes negative values in the GLDAS data that has been regridded.

# %%
import os
import xarray as xr

# %%
ncdata = '../example_data/GLDAS/FORCING'

# %%
# list the FORCING files
ncfiles = []
for file in os.listdir(ncdata):
    if file.endswith("LDASIN_DOMAIN1"):
        ncfiles.append(os.path.join(ncdata, file))
        print(file)
# Out:
# 2019022600.LDASIN_DOMAIN1
# 2019022603.LDASIN_DOMAIN1
# 2019022606.LDASIN_DOMAIN1
# 2019022609.LDASIN_DOMAIN1
# 2019022612.LDASIN_DOMAIN1
# 2019022615.LDASIN_DOMAIN1
# 2019022618.LDASIN_DOMAIN1
# 2019022621.LDASIN_DOMAIN1
# 2019022700.LDASIN_DOMAIN1
# 2019022703.LDASIN_DOMAIN1
# 2019022706.LDASIN_DOMAIN1
# 2019022709.LDASIN_DOMAIN1
# 2019022712.LDASIN_DOMAIN1
# 2019022715.LDASIN_DOMAIN1
# 2019022718.LDASIN_DOMAIN1
# 2019022721.LDASIN_DOMAIN1
# 2019022800.LDASIN_DOMAIN1
# 2019022803.LDASIN_DOMAIN1
# 2019022806.LDASIN_DOMAIN1
# 2019022809.LDASIN_DOMAIN1
# 2019022812.LDASIN_DOMAIN1
# 2019022815.LDASIN_DOMAIN1

# %%
# load data using xarray
ds = xr.open_dataset(ncfiles[0])

# %%
for ncf in ncfiles:
    ds = xr.open_dataset(ncf)
    variables = list(ds.variables)
    print(ncf.split('/')[-1])
    for v in variables:
        if hasattr(ds[v], 'vmin'):
            minimum = ds[v].vmin
            #if minimum < 0:
            print('%10s:\t%3.2f - %3.2f' % (v, ds[v].vmin, ds[v].vmax))
    print('\n')
# Out:
# 2019022600.LDASIN_DOMAIN1
#        T2D:	232.54 - 310.78
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 22.50
#        V2D:	0.00 - 22.50
#       PSFC:	46444.84 - 103688.23
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1126.03
#     LWDOWN:	118.01 - 481.83
#
#
# 2019022603.LDASIN_DOMAIN1
#        T2D:	232.30 - 316.98
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 22.61
#        V2D:	0.01 - 22.61
#       PSFC:	46499.95 - 103713.34
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1233.18
#     LWDOWN:	115.34 - 482.21
#
#
# 2019022606.LDASIN_DOMAIN1
#        T2D:	232.10 - 319.30
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 26.10
#        V2D:	0.00 - 26.10
#       PSFC:	46497.25 - 103625.95
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1182.80
#     LWDOWN:	114.24 - 481.94
#
#
# 2019022609.LDASIN_DOMAIN1
#        T2D:	232.00 - 319.67
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 27.40
#        V2D:	0.00 - 27.40
#       PSFC:	46460.30 - 103535.20
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1142.93
#     LWDOWN:	113.04 - 481.86
#
#
# 2019022612.LDASIN_DOMAIN1
#        T2D:	232.02 - 319.49
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 28.31
#        V2D:	0.01 - 28.31
#       PSFC:	46480.52 - 103553.02
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1073.87
#     LWDOWN:	113.43 - 490.43
#
#
# 2019022615.LDASIN_DOMAIN1
#        T2D:	232.71 - 317.81
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 27.51
#        V2D:	0.01 - 27.51
#       PSFC:	46525.99 - 103374.29
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1051.97
#     LWDOWN:	115.03 - 487.75
#
#
# 2019022618.LDASIN_DOMAIN1
#        T2D:	234.28 - 316.50
#        Q2D:	0.00 - 0.03
#        U2D:	0.00 - 24.00
#        V2D:	0.00 - 24.00
#       PSFC:	46525.00 - 103337.50
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1322.44
#     LWDOWN:	116.76 - 491.42
#
#
# 2019022621.LDASIN_DOMAIN1
#        T2D:	234.03 - 315.16
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 23.20
#        V2D:	0.00 - 23.20
#       PSFC:	46421.52 - 103285.52
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1011.45
#     LWDOWN:	117.36 - 480.78
#
#
# 2019022700.LDASIN_DOMAIN1
#        T2D:	233.41 - 311.59
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 25.11
#        V2D:	0.01 - 25.11
#       PSFC:	46411.34 - 103293.14
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1076.96
#     LWDOWN:	119.37 - 478.18
#
#
# 2019022703.LDASIN_DOMAIN1
#        T2D:	233.24 - 317.00
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 22.31
#        V2D:	0.01 - 22.31
#       PSFC:	46421.92 - 103434.82
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1353.48
#     LWDOWN:	117.08 - 481.68
#
#
# 2019022706.LDASIN_DOMAIN1
#        T2D:	233.30 - 318.02
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 19.91
#        V2D:	0.01 - 19.91
#       PSFC:	46476.48 - 103588.69
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1199.51
#     LWDOWN:	117.58 - 477.33
#
#
# 2019022709.LDASIN_DOMAIN1
#        T2D:	233.86 - 318.74
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 21.80
#        V2D:	0.00 - 21.80
#       PSFC:	46355.02 - 103823.72
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1050.20
#     LWDOWN:	117.00 - 478.18
#
#
# 2019022712.LDASIN_DOMAIN1
#        T2D:	233.82 - 318.91
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 26.00
#        V2D:	0.00 - 26.00
#       PSFC:	46344.29 - 104051.19
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1067.03
#     LWDOWN:	115.82 - 478.84
#
#
# 2019022715.LDASIN_DOMAIN1
#        T2D:	234.12 - 318.73
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 27.40
#        V2D:	0.00 - 27.40
#       PSFC:	46382.18 - 104176.28
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1031.12
#     LWDOWN:	115.36 - 480.85
#
#
# 2019022718.LDASIN_DOMAIN1
#        T2D:	235.22 - 316.29
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 27.10
#        V2D:	0.00 - 27.10
#       PSFC:	46374.23 - 104374.12
#   RAINRATE:	0.00 - 0.01
#     SWDOWN:	0.00 - 1214.32
#     LWDOWN:	120.36 - 484.46
#
#
# 2019022721.LDASIN_DOMAIN1
#        T2D:	234.57 - 313.98
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 35.61
#        V2D:	0.01 - 35.61
#       PSFC:	46313.88 - 104558.88
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1014.40
#     LWDOWN:	114.26 - 477.98
#
#
# 2019022800.LDASIN_DOMAIN1
#        T2D:	233.89 - 311.08
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 29.01
#        V2D:	0.01 - 29.01
#       PSFC:	46360.23 - 104777.63
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1132.79
#     LWDOWN:	114.11 - 477.49
#
#
# 2019022803.LDASIN_DOMAIN1
#        T2D:	232.83 - 316.47
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 28.50
#        V2D:	0.00 - 28.50
#       PSFC:	46461.20 - 104970.40
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1268.86
#     LWDOWN:	111.66 - 478.71
#
#
# 2019022806.LDASIN_DOMAIN1
#        T2D:	231.14 - 319.20
#        Q2D:	0.00 - 0.02
#        U2D:	0.01 - 25.71
#        V2D:	0.01 - 25.71
#       PSFC:	46548.60 - 105074.50
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1216.42
#     LWDOWN:	109.60 - 486.06
#
#
# 2019022809.LDASIN_DOMAIN1
#        T2D:	231.35 - 318.06
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 23.10
#        V2D:	0.00 - 23.10
#       PSFC:	46529.79 - 105224.89
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1042.46
#     LWDOWN:	107.13 - 481.06
#
#
# 2019022812.LDASIN_DOMAIN1
#        T2D:	230.66 - 318.60
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 22.80
#        V2D:	0.00 - 22.80
#       PSFC:	46584.45 - 105414.55
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1063.96
#     LWDOWN:	106.64 - 483.39
#
#
# 2019022815.LDASIN_DOMAIN1
#        T2D:	230.56 - 319.36
#        Q2D:	0.00 - 0.02
#        U2D:	0.00 - 23.30
#        V2D:	0.00 - 23.30
#       PSFC:	46701.00 - 105397.20
#   RAINRATE:	0.00 - 0.00
#     SWDOWN:	0.00 - 1085.64
#     LWDOWN:	107.26 - 486.04

# %%
ds['T2D'].vmin
# Out:
# 232.54262

# %%
ds.LWDOWN.vmax
# Out:
# 481.82529
