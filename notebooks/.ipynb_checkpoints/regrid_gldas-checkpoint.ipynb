# %%
# %%bash
#
# # install the ncl language in the conda environment, if it's not already installed.
# if  which ncl >/dev/null; then
#     echo NCL is already installed!
# else
#     conda install -y ncl
# fi
# Out:
# NCL is already installed!

# %% [markdown]
# Create the regridding weight file.

# %%
# %%bash
# cd ../example_data/GLDAS
# ./generate_weights.sh
# Out:
# -------------------------------
# Generating regridding weights
#   GRIB File   - ./input_files/GLDAS_NOAH025_3H.A20190226.0000.021.nc4
#   DOMAIN File - ../WRF_hydro_domain/geo_em.d01.nc
# -------------------------------
#  Copyright (C) 1995-2018 - All Rights Reserved
#  University Corporation for Atmospheric Research
#  NCAR Command Language Version 6.5.0
#  The use of this software is governed by a License Agreement.
#  See http://www.ncl.ucar.edu/ for more details.
# (0)	=====> CPU Elapsed Time: rectilinear_to_SCRIP: 1.0638 seconds <=====
# (0)	=====> CPU Elapsed Time: curvilinear_to_SCRIP: 0.0215569 seconds <=====
# (0)	ESMF_regrid_gen_weights: number of processors used: 1
# (0)	--------------------------------------------------
# (0)	ESMF_regrid_gen_weights: the following command is about to be executed on the system:
# (0)	'ESMF_RegridWeightGen --ignore_degenerate  --source SCRIP_GLDAS_bilinear.nc --destination SCRIP_WRFHydro_bilinear.nc --weight ./GLDAS2WRFHydro_weight_bilinear.nc --method bilinear --dst_regional -i'
# (0)	--------------------------------------------------
# (0)	ESMF_regrid_gen_weights: output from 'ESMF_RegridWeightGen':
# (0)	      Starting weight generation with these inputs:
# (1)	        Source File: SCRIP_GLDAS_bilinear.nc
# (2)	        Destination File: SCRIP_WRFHydro_bilinear.nc
# (3)	        Weight File: ./GLDAS2WRFHydro_weight_bilinear.nc
# (4)	        Source File is in SCRIP format
# (5)	        Source Grid is a global grid
# (6)	        Source Grid is a logically rectangular grid
# (7)	        Use the center coordinates of the source grid to do the regrid
# (8)	        Destination File is in SCRIP format
# (9)	        Destination Grid is a regional grid
# (10)	        Destination Grid is a logically rectangular grid
# (11)	        Use the center coordinates of the destination grid to do the regrid
# (12)	        Regrid Method: bilinear
# (13)	        Pole option: ALL
# (14)	        Ignore unmapped destination points
# (15)	        Ignore degenerate cells in the input grids
# (16)	        Line Type: cartesian
# (17)	        Norm Type: dstarea
# (18)	        Extrap. Method: none
# (19)
# (20)	      Completed weight generation successfully.
# (21)
# (0)	--------------------------------------------------
# (0)	ESMF_regrid_gen_weights: 'ESMF_RegridWeightGen' was successful.
# (0)	=====> CPU Elapsed Time: ESMF_regrid_gen_weights: 0.0152493 seconds <=====

# %%
rm -rf ../example_data/GLDAS/output_files

# %% [markdown]
# Regrid all of the NLDAS files in the `input_files` directory using the NLDAS2WRFHydro_regrid.ncl script. This script takes NLDAS data and a weight file as inputs and outputs regridded data.

# %%
# %%bash
# cd ../example_data/GLDAS
# ./gldas_regrid.sh
# Out:
#  Copyright (C) 1995-2018 - All Rights Reserved
#  University Corporation for Atmospheric Research
#  NCAR Command Language Version 6.5.0
#  The use of this software is governed by a License Agreement.
#  See http://www.ncl.ucar.edu/ for more details.
# (0)	 ... Open input file : ./input_files/GLDAS_NOAH025_3H.A20190226.0000.021.nc4
#
#
# Variable: date_vec
# Type: string
# Total Size: 56 bytes
#             7 values
# Number of Dimensions: 1
# Dimensions and sizes:	[7]
# Coordinates:
# (0)	A
# (1)	2019
# (2)	02
# (3)	26
# (4)	00
# (5)	0
# (6)	0
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	K
#   standard_name :	air_temperature
#   long_name :	Temperature
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	232.5426
#   vmax :	310.7826
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	kg kg-1
#   standard_name :	specific_humidity
#   long_name :	Specific humidity
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	2.352056e-05
#   vmax :	0.02106352
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	m s-1
#   standard_name :	wind_speed
#   long_name :	Wind speed
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	0.004969045
#   vmax :	22.50497
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [600] x [1440]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.96921e+36
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	Pa
#   standard_name :	surface_air_pressure
#   long_name :	Pressure
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	46444.84
#   vmax :	103688.2
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 11
#   description :	RAINRATE
#   units :	mm s^-1
#   standard_name :	precipitation_flux
#   long_name :	RAINRATE
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	0.009105
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_shortwave_flux_in_air
#   long_name :	Downward short-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	1126.03
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074060..10074060]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_longwave_flux_in_air
#   long_name :	Downward long-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	118.0053
#   vmax :	481.8253
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	 ... Open input file : ./input_files/GLDAS_NOAH025_3H.A20190226.0300.021.nc4
#
#
# Variable: date_vec
# Type: string
# Total Size: 56 bytes
#             7 values
# Number of Dimensions: 1
# Dimensions and sizes:	[7]
# Coordinates:
# (0)	A
# (1)	2019
# (2)	02
# (3)	26
# (4)	03
# (5)	0
# (6)	0
# warning:VarVarWrite: Dimension names for dimension number (0) don't match, assigning name of rhs dimension to lhs, use "(/../)" if this change is not desired
# warning:["Execute.c":8637]:Execute: Error occurred at or near line 123 in file GLDAS2WRFHydro_regrid.ncl
#
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	K
#   standard_name :	air_temperature
#   long_name :	Temperature
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	232.2991
#   vmax :	316.9791
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	kg kg-1
#   standard_name :	specific_humidity
#   long_name :	Specific humidity
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	4.999892e-05
#   vmax :	0.02205
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	m s-1
#   standard_name :	wind_speed
#   long_name :	Wind speed
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	0.007905686
#   vmax :	22.60791
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [600] x [1440]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.96921e+36
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	Pa
#   standard_name :	surface_air_pressure
#   long_name :	Pressure
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	46499.95
#   vmax :	103713.3
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 11
#   description :	RAINRATE
#   units :	mm s^-1
#   standard_name :	precipitation_flux
#   long_name :	RAINRATE
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	0.0040375
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_shortwave_flux_in_air
#   long_name :	Downward short-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	1233.18
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074240..10074240]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_longwave_flux_in_air
#   long_name :	Downward long-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	115.3437
#   vmax :	482.2137
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	 ... Open input file : ./input_files/GLDAS_NOAH025_3H.A20190226.0600.021.nc4
#
#
# Variable: date_vec
# Type: string
# Total Size: 56 bytes
#             7 values
# Number of Dimensions: 1
# Dimensions and sizes:	[7]
# Coordinates:
# (0)	A
# (1)	2019
# (2)	02
# (3)	26
# (4)	06
# (5)	0
# (6)	0
# warning:VarVarWrite: Dimension names for dimension number (0) don't match, assigning name of rhs dimension to lhs, use "(/../)" if this change is not desired
# warning:["Execute.c":8637]:Execute: Error occurred at or near line 123 in file GLDAS2WRFHydro_regrid.ncl
#
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	K
#   standard_name :	air_temperature
#   long_name :	Temperature
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	232.1041
#   vmax :	319.3041
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	kg kg-1
#   standard_name :	specific_humidity
#   long_name :	Specific humidity
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	5.178715e-05
#   vmax :	0.02427179
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	m s-1
#   standard_name :	wind_speed
#   long_name :	Wind speed
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	26.1
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [600] x [1440]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.96921e+36
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	Pa
#   standard_name :	surface_air_pressure
#   long_name :	Pressure
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	46497.25
#   vmax :	103626
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 11
#   description :	RAINRATE
#   units :	mm s^-1
#   standard_name :	precipitation_flux
#   long_name :	RAINRATE
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	0.0030825
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_shortwave_flux_in_air
#   long_name :	Downward short-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	1182.8
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074420..10074420]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_longwave_flux_in_air
#   long_name :	Downward long-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	114.2408
#   vmax :	481.9408
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	 ... Open input file : ./input_files/GLDAS_NOAH025_3H.A20190226.0900.021.nc4
#
#
# Variable: date_vec
# Type: string
# Total Size: 56 bytes
#             7 values
# Number of Dimensions: 1
# Dimensions and sizes:	[7]
# Coordinates:
# (0)	A
# (1)	2019
# (2)	02
# (3)	26
# (4)	09
# (5)	0
# (6)	0
# warning:VarVarWrite: Dimension names for dimension number (0) don't match, assigning name of rhs dimension to lhs, use "(/../)" if this change is not desired
# warning:["Execute.c":8637]:Execute: Error occurred at or near line 123 in file GLDAS2WRFHydro_regrid.ncl
#
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	K
#   standard_name :	air_temperature
#   long_name :	Temperature
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	232.0041
#   vmax :	319.6741
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	kg kg-1
#   standard_name :	specific_humidity
#   long_name :	Specific humidity
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	1.00715e-08
#   vmax :	0.02326001
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	m s-1
#   standard_name :	wind_speed
#   long_name :	Wind speed
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	0.002499999
#   vmax :	27.4025
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [600] x [1440]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.96921e+36
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	Pa
#   standard_name :	surface_air_pressure
#   long_name :	Pressure
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	46460.3
#   vmax :	103535.2
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 11
#   description :	RAINRATE
#   units :	mm s^-1
#   standard_name :	precipitation_flux
#   long_name :	RAINRATE
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	0.0041025
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_shortwave_flux_in_air
#   long_name :	Downward short-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	1142.93
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074600..10074600]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_longwave_flux_in_air
#   long_name :	Downward long-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	113.0352
#   vmax :	481.8552
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	 ... Open input file : ./input_files/GLDAS_NOAH025_3H.A20190226.1200.021.nc4
#
#
# Variable: date_vec
# Type: string
# Total Size: 56 bytes
#             7 values
# Number of Dimensions: 1
# Dimensions and sizes:	[7]
# Coordinates:
# (0)	A
# (1)	2019
# (2)	02
# (3)	26
# (4)	12
# (5)	0
# (6)	0
# warning:VarVarWrite: Dimension names for dimension number (0) don't match, assigning name of rhs dimension to lhs, use "(/../)" if this change is not desired
# warning:["Execute.c":8637]:Execute: Error occurred at or near line 123 in file GLDAS2WRFHydro_regrid.ncl
#
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074780..10074780]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	K
#   standard_name :	air_temperature
#   long_name :	Temperature
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	232.0172
#   vmax :	319.4872
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074780..10074780]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	kg kg-1
#   standard_name :	specific_humidity
#   long_name :	Specific humidity
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	3.272494e-05
#   vmax :	0.02331273
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10074780..10074780]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	m s-1
#   standard_name :	wind_speed
#   long_name :	Wind speed
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	0.005270462
#   vmax :	28.30527
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [600] x [1440]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.96921e+36
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# ...
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077660..10077660]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	Pa
#   standard_name :	surface_air_pressure
#   long_name :	Pressure
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	46584.45
#   vmax :	105414.5
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077660..10077660]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 11
#   description :	RAINRATE
#   units :	mm s^-1
#   standard_name :	precipitation_flux
#   long_name :	RAINRATE
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	0.0042855
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077660..10077660]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_shortwave_flux_in_air
#   long_name :	Downward short-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	1063.96
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077660..10077660]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_longwave_flux_in_air
#   long_name :	Downward long-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	106.6395
#   vmax :	483.3895
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	 ... Open input file : ./input_files/GLDAS_NOAH025_3H.A20190228.1500.021.nc4
#
#
# Variable: date_vec
# Type: string
# Total Size: 56 bytes
#             7 values
# Number of Dimensions: 1
# Dimensions and sizes:	[7]
# Coordinates:
# (0)	A
# (1)	2019
# (2)	02
# (3)	28
# (4)	15
# (5)	0
# (6)	0
# warning:VarVarWrite: Dimension names for dimension number (0) don't match, assigning name of rhs dimension to lhs, use "(/../)" if this change is not desired
# warning:["Execute.c":8637]:Execute: Error occurred at or near line 123 in file GLDAS2WRFHydro_regrid.ncl
#
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	K
#   standard_name :	air_temperature
#   long_name :	Temperature
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	230.5645
#   vmax :	319.3644
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	kg kg-1
#   standard_name :	specific_humidity
#   long_name :	Specific humidity
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	2.947423e-05
#   vmax :	0.02165947
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	m s-1
#   standard_name :	wind_speed
#   long_name :	Wind speed
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	0.003535536
#   vmax :	23.30354
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [600] x [1440]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.96921e+36
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	Pa
#   standard_name :	surface_air_pressure
#   long_name :	Pressure
#   cell_methods :	time: point
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	46701
#   vmax :	105397.2
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 11
#   description :	RAINRATE
#   units :	mm s^-1
#   standard_name :	precipitation_flux
#   long_name :	RAINRATE
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	0.0028507
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_shortwave_flux_in_air
#   long_name :	Downward short-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	 0
#   vmax :	1085.64
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
#
# Variable: var
# Type: float
# Total Size: 3456000 bytes
#             864000 values
# Number of Dimensions: 3
# Dimensions and sizes:	[time | 1] x [lat | 600] x [lon | 1440]
# Coordinates:
#             time: [10077840..10077840]
#             lat: [-59.875..89.875]
#             lon: [-179.875..179.875]
# Number Of Attributes: 10
#   units :	W m-2
#   standard_name :	surface_downwelling_longwave_flux_in_air
#   long_name :	Downward long-wave radiation flux
#   cell_methods :	time: mean
#   scale_factor :	 1
#   add_offset :	 0
#   missing_value :	-9999
#   _FillValue :	-9999
#   vmin :	107.2569
#   vmax :	486.037
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[1] x [56] x [72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36
# (0)	ESMF_regrid_with_weights: regridding using interpolation weights ...
# (0)	ESMF_regrid_with_weights: error: there are no weights on this file.
# (0)	    This likely means there was a problem with the mapping
# (0)	    from the source grid to the destination grid.
# (0)	    Check that both grids are valid.
#
# Variable: v4
# Type: double
# Total Size: 32256 bytes
#             4032 values
# Number of Dimensions: 3
# Dimensions and sizes:	[Time | 1] x [south_north | 56] x [west_east | 72]
# Coordinates:
# Number Of Attributes: 1
#   _FillValue :	9.969209968386869e+36

# %%
# !ls ../example_data/GLDAS
# Out:
# FORCING				     input_files
# generate_weights.sh		     output_files
# GLDAS2WRFHydro_generate_weights.ncl  PET0.RegridWeightGen.Log
# GLDAS2WRFHydro_regrid.ncl	     SCRIP_GLDAS_bilinear.nc
# GLDAS2WRFHydro_weight_bilinear.nc    SCRIP_NLDAS_bilinear.nc
# gldas_regrid.sh			     SCRIP_WRFHydro_bilinear.nc
# GLDAS_WRFHydro_generate_weights.ncl  xml

# %% [markdown]
# Clean the our directory by (1) removing the raw NLDAS data that we downloaded from EarthData and (2) rename the default `output_files` directory to `FORCING`.

# %%
# %%bash
#
# #rm -rf input_files
#
# cd ../example_data/GLDAS
# mv output_files/* FORCING
#
# #rmdir output_files
#
# ls FORCING
# Out:
# 2019022600.LDASIN_DOMAIN1
# 2019022603.LDASIN_DOMAIN1
# 2019022606.LDASIN_DOMAIN1
# 2019022609.LDASIN_DOMAIN1
# 2019022612.LDASIN_DOMAIN1
# 2019022615.LDASIN_DOMAIN1
# 2019022618.LDASIN_DOMAIN1
# 2019022621.LDASIN_DOMAIN1
# 2019022700.LDASIN_DOMAIN1
# 2019022703.LDASIN_DOMAIN1
# 2019022706.LDASIN_DOMAIN1
# 2019022709.LDASIN_DOMAIN1
# 2019022712.LDASIN_DOMAIN1
# 2019022715.LDASIN_DOMAIN1
# 2019022718.LDASIN_DOMAIN1
# 2019022721.LDASIN_DOMAIN1
# 2019022800.LDASIN_DOMAIN1
# 2019022803.LDASIN_DOMAIN1
# 2019022806.LDASIN_DOMAIN1
# 2019022809.LDASIN_DOMAIN1
# 2019022812.LDASIN_DOMAIN1
# 2019022815.LDASIN_DOMAIN1
# output_files
# mv: cannot stat 'output_files/*': No such file or directory
# rmdir: failed to remove 'output_files': No such file or directory

# %% [markdown]
# The next notebook demonstrates how these `FORCING` data can be used to run the WRF-Hydro model. However, execution of the model must be completed on your local machine, so first we'll save our data to HydroShare. Replace the `<abstract>`, `<title>`, and `<keyword>`, placeholders below:

# %%
from utilities import hydroshare
hs = hydroshare.hydroshare()

# compress the DOMAIN and FORCING directories
# !tar -czf wrfhydro-data.tar.gz DOMAIN FORCING

# lets save this content as a new resource in HydroShare
abstract = '<abstract>'
title = '<title>'    
keywords = ['<keyword>', '<keyword>2']         

# create the new resource
resource_id = hs.createHydroShareResource(abstract, 
                                          title, 
                                          keywords=keywords, 
                                          resource_type='compositeresource', 
                                          content_files=['wrfhydro-data.tar.gz',
                                                         'WRFHydro-Domain.ipynb',
                                                         'WRFHydro-Forcing.ipynb,
                                                         'WRFHydro-Simulation.ipynb'], 
                                          public=False)
